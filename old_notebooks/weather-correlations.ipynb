# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '../')
import pandas as pd

# %%
data_pc = pd.read_csv('../ts_data/6010.csv', index_col  = [0]).iloc[:, 0:8]

# %%
data_pc.head()
# Out:
#                         power  wind  temperature  dewPoint  cloudCover  \
# date_str
# 2020-02-13 07:00:00      7.22  3.20        21.92     19.28        0.21
# 2020-02-13 08:00:00      3.52  3.17        22.55     19.48        0.00
# 2020-02-13 09:00:00   1784.07  3.51        23.09     19.69        0.00
# 2020-02-13 10:00:00    405.33  4.00        23.98     19.83        0.00
# 2020-02-13 11:00:00  16232.33  4.24        25.35     20.25        0.00
#
#                      humidity  pressure  uvIndex
# date_str
# 2020-02-13 07:00:00      0.85    1011.2        0
# 2020-02-13 08:00:00      0.83    1011.5        0
# 2020-02-13 09:00:00      0.81    1011.9        0
# 2020-02-13 10:00:00      0.78    1012.3        0
# 2020-02-13 11:00:00      0.73    1012.3        2

# %%
df.corr()
# Out:
#                 power      wind  temperature  dewPoint  cloudCover  humidity  \
# power        1.000000 -0.087898     0.453414  0.158433   -0.225768 -0.414086
# wind        -0.087898  1.000000    -0.046560  0.025119    0.063619  0.071182
# temperature  0.453414 -0.046560     1.000000  0.552888   -0.097334 -0.653497
# dewPoint     0.158433  0.025119     0.552888  1.000000    0.177787  0.249246
# cloudCover  -0.225768  0.063619    -0.097334  0.177787    1.000000  0.287666
# humidity    -0.414086  0.071182    -0.653497  0.249246    0.287666  1.000000
# pressure     0.017927 -0.361700    -0.440135 -0.503685   -0.167073  0.022609
# uvIndex      0.842647 -0.017137     0.607227  0.300104   -0.229901 -0.444486
#
#              pressure   uvIndex
# power        0.017927  0.842647
# wind        -0.361700 -0.017137
# temperature -0.440135  0.607227
# dewPoint    -0.503685  0.300104
# cloudCover  -0.167073 -0.229901
# humidity     0.022609 -0.444486
# pressure     1.000000 -0.183542
# uvIndex     -0.183542  1.000000

# %%
df = data_pc

f = plt.figure(figsize=(6, 5))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
