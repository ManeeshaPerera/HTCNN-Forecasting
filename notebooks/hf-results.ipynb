# %%
import sys
sys.path.insert(0, '../')

import src.utils as util
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import pandas as pd
import pickle
import numpy as np

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import src.post_process as pp
import src.calculate_errors as err
import src.utils as util

# %% [markdown]
# Calculate Errors from the models

# %%
data = pd.read_pickle('../input/solar_timeseries')

# %%
test_actual = data['grid'][int(len(data)*0.9):]

# %%
len(test_actual)
# Out:
# 6235

# %% [markdown]
# Loss Graph

# %%
loss = []
trace_names = []
for col in data.columns[0:1]:
    nn_loss = pd.read_pickle(f'../fc_results/training_loss_{str(col)}')
    loss.append(nn_loss)
    trace_names.append(str(col))

# %%
util.plot_multiple_loss(loss, trace_names)
# Out:
# <div>                            <div id="c5363036-3de8-449e-aad9-c41df8cb8578" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5363036-3de8-449e-aad9-c41df8cb8578")) {                    Plotly.newPlot(                        "c5363036-3de8-449e-aad9-c41df8cb8578",                        [{"name": "grid", "type": "scatter", "y": [0.9191964864730835, 0.49080541729927063, 0.281632661819458, 0.19356298446655273, 0.13999596238136292, 0.10942487418651581, 0.08813411742448807, 0.0719783827662468, 0.0625845193862915, 0.057229455560445786, 0.053824037313461304, 0.05161358043551445, 0.049970243126153946, 0.048606548458337784, 0.04737405478954315, 0.04622235521674156, 0.045133501291275024, 0.044116564095020294, 0.04323490709066391, 0.04247269034385681, 0.04180888459086418, 0.041173167526721954, 0.04053695127367973, 0.039928138256073, 0.03941443935036659, 0.038991980254650116, 0.03860132396221161, 0.0382252037525177, 0.03789161145687103, 0.03760534152388573, 0.03735891357064247, 0.037150152027606964, 0.03697339445352554, 0.03682320937514305, 0.03669489547610283, 0.03658425062894821, 0.03648783639073372, 0.0364028662443161, 0.03632717579603195, 0.03625909984111786, 0.03619740530848503, 0.03614119067788124, 0.03608978912234306, 0.03604268655180931, 0.03599945455789566, 0.03595971316099167, 0.03592309728264809, 0.03588922694325447, 0.03585772588849068, 0.03582822531461716, 0.03580038994550705, 0.035773925483226776, 0.03574860468506813, 0.03572426736354828, 0.03570079803466797, 0.03567812964320183, 0.03565621376037598, 0.035635001957416534, 0.03561445325613022, 0.03559451550245285, 0.03557513654232025, 0.03555626794695854, 0.03553786128759384, 0.03551986441016197, 0.035502251237630844, 0.035485006868839264, 0.03546810895204544, 0.03545157238841057, 0.035435426980257034, 0.035419706255197525, 0.03540447726845741, 0.03538980707526207, 0.03537578880786896, 0.03536251559853554, 0.03535010665655136, 0.0353386253118515, 0.035328153520822525, 0.035318680107593536, 0.03531014919281006, 0.03530240058898926, 0.03529522567987442, 0.035288333892822266, 0.03528151661157608, 0.03527455031871796, 0.03526739403605461, 0.03526001796126366, 0.0352526418864727, 0.035245250910520554, 0.03523819521069527, 0.03523124009370804, 0.03522493317723274, 0.03521854802966118, 0.03521314263343811, 0.03520715609192848, 0.03520280122756958, 0.03519689291715622, 0.03519397974014282, 0.03518777713179588, 0.03518722206354141, 0.035180624574422836, 0.035184890031814575, 0.035179466009140015, 0.03519638255238533, 0.03519861027598381, 0.03525516018271446, 0.03524539992213249, 0.035380132496356964, 0.035304006189107895, 0.03526203706860542, 0.03516291454434395, 0.035174962133169174, 0.03514945134520531, 0.0351998470723629,
# 2021-01-13 16:30:00     3665.89     4260.08     7877.86     5357.55
# 2021-01-13 16:35:00     3639.66     4210.64     7848.79     5341.51
# 2021-01-13 16:40:00     3592.20     4172.70     7807.51     5309.37
# 2021-01-13 16:45:00     3570.80     4061.25     7972.69     5357.97
#
#                      1708098535  456209269
# date_str
# 2021-01-13 16:25:00     4864.87    5016.53
# 2021-01-13 16:30:00     4800.09    4836.32
# 2021-01-13 16:35:00     4800.98    4888.94
# 2021-01-13 16:40:00     4762.92    4898.84
# 2021-01-13 16:45:00     4719.10    5048.65
#
# [5 rows x 39 columns]

# %%
mase_vals, mase_ls = err.calculate_errors(data, fc_df, 1, 3)

# %%
len(mase_vals)
# Out:
# 39

# %%
# fig = go.Figure()
# for col in fc_df.keys():
#     box_data = mase_ls[col]
#     fig.add_trace(go.Box(y=box_data, name = col))
# fig.update_xaxes(title = 'time series')
# fig.update_yaxes(title = 'MASE')
# fig.update_layout(showlegend = False)

# %%
# fig = go.Figure()
# fig.add_trace(go.Bar(x = fc_df.columns.tolist(), y=mase_vals))
# fig.update_xaxes(title = 'time series')
# fig.update_yaxes(title = 'mean MASE')

# %% [markdown]
# Calculate the errors at the top level of the hierarchy

# %%
grid_fc = fc_df[['grid']]

# %%
tl_level = fc_df.iloc[:,[1,2]]
substation_level = fc_df.iloc[:,3:7]
pc_level = fc_df.iloc[:,7:13]
house_level = fc_df.iloc[:,13:]

# %%
tl_level_df = pd.DataFrame(tl_level.sum(axis=1), columns = ['tl'])
substation_level_df = pd.DataFrame(substation_level.sum(axis=1), columns = ['substation'])
pc_level_df = pd.DataFrame(pc_level.sum(axis=1), columns = ['pc_level'])
house_level_df = pd.DataFrame(house_level.sum(axis=1), columns = ['house'])

# %%
grid_fc = pd.concat([grid_fc, tl_level_df, substation_level_df, pc_level_df, house_level_df], axis=1)

# %%
mase_ls_grid = []
mase_dic = {}

train = data['grid'][0:int(len(data)*0.7)]
denom = err.calculate_denom(train, 1)

for col in grid_fc.columns:
    forecasts = grid_fc[col].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid.append(mase)
    mase_dic[col] = mase_arr

# %%
mase_ls_grid
# Out:
# [0.9609531942355383,
#  0.9452244281536608,
#  0.9605070821568917,
#  1.014553832701932,
#  1.0255598367623544]

# %%
# mase_dic['grid']

# %%
# fig = go.Figure()
# fig.add_trace(go.Bar(x = ['TD', 'Transimission Zone Level (BU)', 'Substation Level (BU)', 
#                           'Postcode Level (BU)', 'House Level (BU)'], y=mase_ls_grid))
# fig.update_xaxes(title = 'Forecast strategy')
# fig.update_yaxes(title = 'mean MASE')

# %%
# dic_conv = {'grid': 'TD', 'tl':'Transimission Zone Level (BU)', 'substation': 'Substation Level (BU)', 
#                           'pc_level':'Postcode Level (BU)', 'house':'House Level (BU)'}

# fig = go.Figure()
# for col in mase_dic.keys():
#     box_data = mase_dic[col]
#     fig.add_trace(go.Box(y=box_data, name = dic_conv[col]))
# fig.update_xaxes(title = 'Forecast strategy')
# fig.update_yaxes(title = 'MASE')
# Out:
# <div>                            <div id="8aa532cd-0e0d-4f0d-ae8b-8240355ca438" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
630662, 0.6054916250839667, 0.46381732909747275, 0.32351705305612966, 0.33152176691570473, 0.12597828034438527, 0.2171326002878147, 0.24027917443848623, 0.07616582203427115, 0.06874557934539464, 0.033266708075058396, 0.0011105398064162008, 0.03826213100998153, 0.09847068636779538, 0.10881105580577906, 0.10312817707740198, 0.1028161024629936, 0.10278222007628639, 0.10257491336814366, 0.10266987321509935, 0.1134828127834729, 0.11546537822672172, 0.041308425067485 ...

# %% [markdown]
# Plot the forecasts

# %%
def plot_fc(data, fc):
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=data.index, y=data.values, name ='target generation'))
    fig.add_trace(go.Scatter(x=fc.index, y=fc.values, name ='forecasts'))
    fig.show()

# %%
# plot_fc(test_actual, fc['grid'])

# %%
train = data['grid'][int(len(data)*0.7):]

# %%
dm = err.calculate_denom(train, 1)

# %%
dm
# Out:
# 4308.036596647299

# %%
mase, error = err.test_errors(train, test_actual, fc['grid'].values, 3, 1, dm)

# %%
len(train)
# Out:
# 31796

# %%
mase
# Out:
# 1.654953800219155

# %%
fig = go.Figure()
fig.add_trace(go.Box(y=error, name = 'fc - grid level'))
# Out:
# <div>                            <div id="b0064cfa-c8b6-414b-a79d-7e19222423a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0064cfa-c8b6-414b-a79d-7e19222423a4")) {                    Plotly.newPlot(                        "b0064cfa-c8b6-414b-a79d-7e19222423a4",                        [{"name": "fc - grid level", "type": "box", "y": [0.1858809988816269, 0.18608191068519975, 0.18630705951320123, 0.1865110818852681, 0.18540793683683784, 0.18653522541394618, 0.18634638678978532, 0.1867544356213244, 0.18606965051429028, 0.18599717087939038, 0.18713793681480637, 0.18611157160364467, 0.18685176587684107, 0.1860268984535787, 0.18550370018910747, 0.22916600106508514, 1.412048157751831, 1.480322146800934, 0.6267997847697088, 0.13872479185709954, 0.7189343035394259, 2.983159769354019, 2.350918394741741, 3.385882776163976, 3.230879855000262, 6.264099957024917, 1.1196129729362259, 3.4759815251657504, 3.8259145431631203, 7.612070621903811, 2.4531678563048347, 3.48813312968284, 5.353510856384504, 7.628676542458262, 4.4688386740600805, 11.75284507592132, 3.455257861666475, 7.547261847309535, 5.080138936539637, 6.422320659772527, 6.311100631488173, 4.257778432779047, 1.0895894519298326, 1.8407153930879863, 1.5249203055470588, 4.492982384869655, 6.002651834031018, 16.84924915979258, 5.61869467473286, 3.0373319780366117, 4.473394406419085, 4.937277823238853, 3.269908783478211, 7.742308463323543, 7.20510250020175, 7.646867434424524, 2.3781864986396566, 4.475135345676239, 7.714332386264549, 1.9247043060777316, 5.946333935161618, 0.41480047587077123, 5.452210434807848, 6.806423910644302, 2.1860874185998895, 2.679700236400766, 1.9476872463153432, 2.1636173908464804, 0.13811188697508006, 0.9020460795162552, 1.0090038450395165, 0.19491691941651124, 0.014995246271244184, 0.1200397831419212, 0.13344876337513636, 0.180017205915993, 0.15974237478815537, 0.21519186996829087, 0.18384368104356172, 0.18539351914720634, 0.1862664393884671, 0.18582876871153323, 0.185945815098396, 0.18586920438845947, 0.18705111254899887, 0.185980789580086, 0.1849091796806005, 0.1873755792812192, 0.1864391356129987, 0.18652526504908382, 0.18689727318824514, 0.18609970713918608, 0.1864
# 2  1785.224286  1733.961429  1087.384286  1136.372857  1006.577143
# 3  1458.507143  4458.514286  2816.281429  2590.491429  2703.689286
# 4  2457.620714  4670.427143  2725.972143  2782.651429  2718.415714
#
# [5 rows x 40 columns]

# %%
test = df.loc[df['date_str']>=val_start]

# %%
train = df.loc[df['date_str']<val_start]['grid']

# %%
mean = 110852.73482653

# %%
cnn_1 = pd.read_csv('../fc_results/cnn_results.csv', index_col = [0])+mean

# %%
cnn_1
# Out:
#            target          cnn-1     dilation-2     dilation-3     dilation-5
# 0   160728.371429  151911.039514  136951.519983  142029.555139  154962.691858
# 1   166689.189286  135160.857873  136029.236780  138843.844202  154204.250452
# 2   147175.335714  136548.098108  135684.809045  135422.107873  162605.117639
# 3   162933.855000  174222.742639  149049.055139  144454.820764  182452.391077
# 4   179447.513571  169430.016077  154219.402795  156040.602014  189911.555139
# 5   170105.036429  168720.285608  156401.168420  168850.988733  215178.883264
# 6    52420.040714  151121.699670  143084.123498  133185.557092  171406.730920
# 7    30890.923571  138004.666467  132703.545373  137849.803186  168895.613733
# 8   124078.987857  136001.557092  137699.687952  121560.724084  164855.652795
# 9   135138.137857  138406.129358  144989.887170  133881.541467  166990.316858
# 10  152992.575000  157138.312952  149858.879358  144746.371545  190995.266077
# 11  130977.402857  159863.242639  158867.484827  154889.613733  177198.875452
# 12  178444.978571  171223.664514  159888.363733  170091.449670  198502.687952
# 13  151616.468571  146979.269983  139870.922327  148990.297327  181028.250452
# 14  144059.191429  138801.900842  136411.443811  141794.424280  160609.836389

# %%
cnn_exg = pd.read_csv('../fc_results/cnnexg.csv', index_col = [0])+mean

# %%
cnn_exg
# Out:
#            cnn-1     dilation-2     dilation-3     dilation-5
# 0  164571.184045  178075.219202  173818.891077  178941.883264
# 1  142148.986780  185067.148889  176836.750452  184057.328577
# 2  135429.506311  159192.109827  154726.879358  160898.344202

# %%
cnn_2 = pd.read_csv('../fc_results/wavenet_results.csv', index_col = [0])+mean

# %%
cnn_exg2 = pd.read_csv('../fc_results/wavenetexg.csv', index_col = [0])+mean

# %%
denom = err.calculate_denom(train, 3)

# %%
denom
# Out:
# 25143.60411120129

# %%
mase_ls_grid1 = []
mase_dic ={}

for col in cnn_1.columns[1:]:
    forecasts = cnn_1[col][0:3].values
    test_actual = cnn_1['target'][0:3].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid1.append(mase)
    mase_dic[col] = mase_arr

# %%
mase_dic
# Out:
# {'cnn-1': [0.6757570196635202],
#  'dilation-2': [0.8740106142471479],
#  'dilation-3': [0.7728590931352518],
#  'dilation-5': [0.4465071936487011]}

# %%
mase_ls_grid1
# Out:
# [0.6757570196635202,
#  0.8740106142471479,
#  0.7728590931352518,
#  0.4465071936487011]

# %%
cnn_1['target'][0:3].values
# Out:
# array([160728.37142857, 166689.18928571, 147175.33571429])

# %%
mase_ls_gridexg = []

for col in cnn_exg.columns:
    forecasts = cnn_exg[col].values
    test_actual = cnn_1['target'][0:3].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_gridexg.append(mase)

# %%
mase_ls_gridexg
# Out:
# [0.5319953913352041,
#  0.6329188300051228,
#  0.40818365207441887,
#  0.6536408410327524]

# %%
# fig = go.Figure()
# for col in mase_dic.keys():
#     box_data = mase_dic[col]
#     fig.add_trace(go.Box(y=box_data, name = col))
# fig.update_xaxes(title = 'TCN')
# fig.update_yaxes(title = 'MASE')

# %%
mase_ls_grid2 = []
# mase_dic ={}

for col in cnn_2.columns[1:]:
    forecasts = cnn_2[col][0:3].values
    test_actual = cnn_2['target'][0:3].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid2.append(mase)
    mase_dic["wv-" + col] = mase_arr

# %%
mase_ls_grid2
# Out:
# [0.29788330951341574,
#  0.4123980699808946,
#  0.32417530480214324,
#  0.38846378473023413]

# %%
mase_ls_grid2exg
# Out:
# [0.48976351389843575,
#  0.9998236785245584,
#  0.27633909427862857,
#  0.8246981699117457]

# %%
mase_ls_grid2exg = []
# mase_dic ={}

for col in cnn_exg2.columns:
    forecasts = cnn_exg2[col].values
    test_actual = cnn_2['target'][0:3].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid2exg.append(mase)
#     mase_ls_grid2exg["wv-" + col] = mase_arr

# %%
arima = pd.read_csv('../fc_results/arima.csv', index_col = [0])

# %%
mase_ls_grid3 = []
# mase_dic ={}

for col in arima.columns:
    forecasts = arima[col].values
    test_actual = cnn_2['target'].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid3.append(mase)
    mase_dic[col] = mase_arr

# %%
mase_ls_grid3
# Out:
# [1.2585419615505855]

# %%
rnn = pd.read_pickle('../fc_results/forecast_rnn')

# %%
fc_ls = []
for batch in rnn:
    batch_data = batch[::3]
    for h in batch_data:
        fc_ls.extend(h.tolist())

# %%
rnn_df = pd.DataFrame(fc_ls[-15:], columns = ['rnn'])

# %%
train_df = train[0:-50]

# %%
rnn_df = (rnn_df * train_df.std()) + train_df.mean()

# %%
mase_ls_grid4 = []
# mase_dic ={}

for col in rnn_df.columns:
    forecasts = rnn_df[col].values
    test_actual = cnn_2['target'].values
    mase, mase_arr = err.test_errors(train, test_actual, forecasts, 3, 1, denom)
    mase_ls_grid4.append(mase)
    mase_dic[col] = mase_arr

# %%
mase_ls_grid4
# Out:
# [1.1571992315721709]

# %%
for key in mase_dic:
    print(key)
    print(np.median(mase_dic[key]))
    print(mase_dic[key])
# Out:
# cnn-1
# 0.48122999224131485
# [0.6757570196635202, 0.3008205168779632, 2.886591889316485, 0.48122999224131485, 0.22690731682385337]
# dilation-2
# 0.7002016418942705
# [0.8740106142471479, 0.7002016418942705, 2.732270783045378, 0.5418942957152165, 0.5031088427547701]
# dilation-3
# 0.5719147408669689
# [0.7728590931352518, 0.5719147408669689, 2.5220815457186183, 0.4429888753227469, 0.17558431210293843]
# dilation-5
# 0.9950366721180716
# [0.4465071936487011, 0.9950366721180716, 3.947565140735351, 1.5388451891276411, 0.875240954965188]
# wv-wavenet-1
# 0.6197897907905824
# [0.29788330951341574, 0.6197897907905824, 3.5169342242858517, 0.5676275732870565, 0.6660521944701009]
# wv-dilation-2
# 0.5465826491323335
# [0.4123980699808946, 0.704489149164107, 3.4754557128433046, 0.4264044073759245, 0.5465826491323335]
# wv-dilation-2/k4
# 0.5628590155596797
# [0.32417530480214324, 0.3685882789582973, 3.8220361478302625, 0.6998510718084705, 0.5628590155596797]
# wv-dilation-3
# 0.6975187197071812
# [0.38846378473023413, 0.6975187197071812, 3.388908220455481, 0.9249916812903388, 0.6883617012444342]
# arima
# 0.4326840707564575
# [0.29942732328139104, 0.4136240024636731, 3.92665502783799, 0.4326840707564575, 1.2203193834134163]
# rnn
# 0.6575582227014222
# [0.2970141435421191, 0.6575582227014222, 3.5446918847829925, 0.5555700403907842, 0.7311618664435354]

# %%
labels = ['tcn', 'tcn-d^2', 'tcn-d^3', 'tcn-d^5', 'wv', 'wv-d^2', 'wv-d^2/k4', 'wv-d^3', 'auto-arima', 'rnn']

fig = go.Figure()
i=0
for col in mase_dic.keys():
    box_data = mase_dic[col]
    fig.add_trace(go.Box(y=box_data, name = labels[i], boxmean=True))
    i = i+1
fig.update_xaxes(title = 'Convolution Networks')
fig.update_yaxes(title = 'MASE')
fig.update_layout(showlegend = False)
# Out:
# <div>                            <div id="8ac8d1db-736a-45e6-91dd-8e7387dacdad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ac8d1db-736a-45e6-91dd-8e7387dacdad")) {                    Plotly.newPlot(                        "8ac8d1db-736a-45e6-91dd-8e7387dacdad",                        [{"boxmean": true, "name": "tcn", "type": "box", "y": [0.6757570196635202, 0.3008205168779632, 2.886591889316485, 0.48122999224131485, 0.22690731682385337]}, {"boxmean": true, "name": "tcn-d^2", "type": "box", "y": [0.8740106142471479, 0.7002016418942705, 2.732270783045378, 0.5418942957152165, 0.5031088427547701]}, {"boxmean": true, "name": "tcn-d^3", "type": "box", "y": [0.7728590931352518, 0.5719147408669689, 2.5220815457186183, 0.4429888753227469, 0.17558431210293843]}, {"boxmean": true, "name": "tcn-d^5", "type": "box", "y": [0.4465071936487011, 0.9950366721180716, 3.947565140735351, 1.5388451891276411, 0.875240954965188]}, {"boxmean": true, "name": "wv", "type": "box", "y": [0.29788330951341574, 0.6197897907905824, 3.5169342242858517, 0.5676275732870565, 0.6660521944701009]}, {"boxmean": true, "name": "wv-d^2", "type": "box", "y": [0.4123980699808946, 0.704489149164107, 3.4754557128433046, 0.4264044073759245, 0.5465826491323335]}, {"boxmean": true, "name": "wv-d^2/k4", "type": "box", "y": [0.32417530480214324, 0.3685882789582973, 3.8220361478302625, 0.6998510718084705, 0.5628590155596797]}, {"boxmean": true, "name": "wv-d^3", "type": "box", "y": [0.38846378473023413, 0.6975187197071812, 3.388908220455481, 0.9249916812903388, 0.6883617012444342]}, {"boxmean": true, "name": "auto-arima", "type": "box", "y": [0.29942732328139104, 0.4136240024636731, 3.92665502783799, 0.4326840707564575, 1.2203193834134163]}, {"boxmean": true, "name": "rnn", "type": "box", "y": [0.2970141435421191, 0.6575582227014222, 3.5446918847829925, 0.5555700403907842, 0.7311618664435354]}],                        {"showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0 ...
